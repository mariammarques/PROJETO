# %%
import pandas as pd

# %%
tracks_df = pd.read_csv('C:/Users/anton/Desktop/Projeto DV/Datasets/tracks.csv')
artists_df = pd.read_csv('C:/Users/anton/Desktop/Projeto DV/Datasets/artists.csv')

# %%
# see the first 5 lines of the dataframe
tracks_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4

# %%
# count missing values
tracks_df.isna().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
# count number of incomplete dates
only_year_series = tracks_df.apply(lambda x: True if len(x['release_date']) != 10 else False, axis=1)
num_rows_only_year = len(only_year_series[only_year_series == True].index)
print("Number of rows that don't have the complete date: ", num_rows_only_year)
# Out:
# Number of rows that don't have the complete date:  138591

# %% [markdown]
# We are going to:
#   1. remove the [ ] from the 'artists' and the 'id_artists' columns
#   2. extract only the year, from the 'release_date' column
#   3. delete the observations with missing values

# %%
tracks_df['artists'] = tracks_df['artists'].map(lambda x: x[2:-2])

# %%
tracks_df['artists'] = tracks_df['artists'].map(lambda x: x.replace("'",""))

# %%
tracks_df['artists'] = tracks_df['artists'].map(lambda x: x.split(','))

# %%
tracks_df['id_artists'] = tracks_df['id_artists'].map(lambda x: x[2:-2])

# %%
tracks_df['id_artists'] = tracks_df['id_artists'].map(lambda x: x.replace("'",""))

# %%
tracks_df['id_artists'] = tracks_df['id_artists'].map(lambda x: x.split(','))

# %%
tracks_df.tail()
# Out:
#                             id                       name  popularity  \
# 586667  5rgu12WBIHQtvej2MdHSH0                        云与海          50
# 586668  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 586670  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#         duration_ms  explicit                       artists  \
# 586667       258267         0                     [阿YueYue]
# 586668       153293         0                  [ROLE MODEL]
# 586669       187601         0                     [FINNEAS]
# 586670       142003         0  [Gentle Bones,  Clara Benin]
# 586671       214360         0                   [Afrosound]
#
#                                                id_artists release_date  \
# 586667                           [1QLBXKM5GCpyQQSVMNZqrZ]   2020-09-26
# 586668                           [1dy5WNgIKQU6ezkpZs4y8z]   2020-10-21
# 586669                           [37M5pPGs6V1fchFJSgCguX]   2020-09-02
# 586670  [4jGPdu95icCKVF31CcFKbS,  5ebPSE9YI5aLeZ1Z2gkqjn]   2021-03-05
# 586671                           [0i4Qda0k4nf7jnNHmSNpYv]   2015-07-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 586667         0.560   0.518    0    -7.471     0       0.0292         0.785
# 586668         0.765   0.663    0    -5.223     1       0.0652         0.141
# 586669         0.535   0.314    7   -12.823     0       0.0408         0.895
# 586670         0.696   0.615   10    -6.212     1       0.0345         0.206
# 586671         0.686   0.723    6    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4

# %%
tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
#  16  liveness          586672 non-null  float64
#  17  valence           586672 non-null  float64
#  18  tempo             586672 non-null  float64
#  19  time_signature    586672 non-null  int64
# dtypes: float64(9), int64(6), object(5)
# memory usage: 89.5+ MB

# %%
tracks_df['release_date'] = pd.to_datetime(tracks_df.release_date)
tracks_df['release_year'] = tracks_df.release_date.dt.year
tracks_df.drop(columns=['release_date'], inplace = True)

# %%
tracks_df = tracks_df.dropna(subset=['name'])

# %%
tracks_df["id"].value_counts()
# Out:
# 5Wl5im0T3R5NdVA4toHFu8    1
# 15XBdkGcDy4WZJlWjF1gZc    1
# 1xNaqY8HBl2mrDk54wF53L    1
# 0bmCBrcEe85IwVyUgykTJK    1
# 0JLJwnfWEbI2G4p4VGGRhy    1
#                          ..
# 7LFJYHe3gafHjFdK97mWGq    1
# 5pR644HD9sFQMkl7xtZELG    1
# 4kbo7522YtoLQI4tENna5L    1
# 0c7iF5fSBYxCuwsAv2z4iI    1
# 4LwU4Vp6od3Sb08CsP99GC    1
# Name: id, Length: 586601, dtype: int64

# %%
tracks_df.set_index('id', inplace = True)

# %%
tracks_df.head()
# Out:
#                                                        name  popularity  \
# id
# 35iwgR4jXetI318WEWsa1Q                                Carve           6
# 021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#                         duration_ms  explicit            artists  \
# id
# 35iwgR4jXetI318WEWsa1Q       126903         0              [Uli]
# 021ht4sdgPcrDgSk7JTbKY        98200         0  [Fernando Pessoa]
# 07A5yehtSnoedViJAZkNnc       181640         0  [Ignacio Corsini]
# 08FmqUhxtyLTn6pAh6bk45       176907         0  [Ignacio Corsini]
# 08y9GfoqCWfOGsKdwojr5e       163080         0      [Dick Haymes]
#
#                                       id_artists  danceability  energy  key  \
# id
# 35iwgR4jXetI318WEWsa1Q  [45tIt06XoI0Iio4LBEVpls]         0.645  0.4450    0
# 021ht4sdgPcrDgSk7JTbKY  [14jtPCOoNZwquk5wd9DxrY]         0.695  0.2630    0
# 07A5yehtSnoedViJAZkNnc  [5LiOoJbxVSAMkBS2fUm3X2]         0.434  0.1770    1
# 08FmqUhxtyLTn6pAh6bk45  [5LiOoJbxVSAMkBS2fUm3X2]         0.321  0.0946    7
# 08y9GfoqCWfOGsKdwojr5e  [3BiJGZsyX9sJchTqcSA7Su]         0.402  0.1580    3
#
#                         loudness  mode  speechiness  acousticness  \
# id
# 35iwgR4jXetI318WEWsa1Q   -13.338     1       0.4510         0.674
# 021ht4sdgPcrDgSk7JTbKY   -22.136     1       0.9570         0.797
# 07A5yehtSnoedViJAZkNnc   -21.180     1       0.0512         0.994
# 08FmqUhxtyLTn6pAh6bk45   -27.961     1       0.0504         0.995
# 08y9GfoqCWfOGsKdwojr5e   -16.900     0       0.0390         0.989
#
#                         instrumentalness  liveness  valence    tempo  \
# id
# 35iwgR4jXetI318WEWsa1Q            0.7440     0.151    0.127  104.851
# 021ht4sdgPcrDgSk7JTbKY            0.0000     0.148    0.655  102.009
# 07A5yehtSnoedViJAZkNnc            0.0218     0.212    0.457  130.418
# 08FmqUhxtyLTn6pAh6bk45            0.9180     0.104    0.397  169.980
# 08y9GfoqCWfOGsKdwojr5e            0.1300     0.311    0.196  103.220
#
#                         time_signature  release_year
# id
# 35iwgR4jXetI318WEWsa1Q               3          1922
# 021ht4sdgPcrDgSk7JTbKY               1          1922
# 07A5yehtSnoedViJAZkNnc               5          1922
# 08FmqUhxtyLTn6pAh6bk45               3          1922
# 08y9GfoqCWfOGsKdwojr5e               4          1922

# %%
artists_df.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
# count missing values
artists_df.isna().sum()
# Out:
# id             0
# followers     13
# genres         0
# name           0
# popularity     0
# dtype: int64

# %%
artists_df = artists_df.dropna(subset=['followers'])

# %%
artists_df.drop(columns=['genres'], inplace = True)

# %%
artists_df["id"].value_counts()
# Out:
# 2og3FOCLYXT9H7IYE6QPUq    1
# 10dHjmJLyAKo1cED1Ds3Sw    1
# 31tDndvclMnUnbnkK24E8c    1
# 4phOzS886EDqLYqFnqS3Zy    1
# 3xPTNrD6oig6iLmXkvy99O    1
#                          ..
# 1tqkHeAaph8dCc8I0MWWxy    1
# 41W2M7fIOODhLqeHOoaDrL    1
# 16RWILO2cJGjM2XnixoQ5w    1
# 5T8x61HRsjZo0CwH1rs6Kf    1
# 034uMYT4nhWX0oKQrUAkia    1
# Name: id, Length: 1104336, dtype: int64

# %%
artists_df.set_index('id', inplace = True)

# %%
artists_df.head()
# Out:
#                         followers  \
# id
# 0DheY5irMjBUeLybbCUEZ2        0.0
# 0DlhY15l3wsrnlfGio2bjU        5.0
# 0DmRESX2JknGPQyO15yxg7        0.0
# 0DmhnbHjm1qw6NCYPeZNgJ        0.0
# 0Dn11fWM7vHQ3rinvWEl4E        2.0
#
#                                                                   name  \
# id
# 0DheY5irMjBUeLybbCUEZ2  Armid & Amir Zare Pashai feat. Sara Rouzbehani
# 0DlhY15l3wsrnlfGio2bjU                                     ปูนา ภาวิณี
# 0DmRESX2JknGPQyO15yxg7                                           Sadaa
# 0DmhnbHjm1qw6NCYPeZNgJ                                       Tra'gruda
# 0Dn11fWM7vHQ3rinvWEl4E                          Ioannis Panoutsopoulos
#
#                         popularity
# id
# 0DheY5irMjBUeLybbCUEZ2           0
# 0DlhY15l3wsrnlfGio2bjU           0
# 0DmRESX2JknGPQyO15yxg7           0
# 0DmhnbHjm1qw6NCYPeZNgJ           0
# 0Dn11fWM7vHQ3rinvWEl4E           0
